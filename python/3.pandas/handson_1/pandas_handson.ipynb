# %% [markdown]
# ### Pandas handsON 1
# * resource:  https://www.youtube.com/watch?v=GEciIuxcWkg

# %%
precos = [1000,1500,1250,2500]
def adicionar_imposto(preco):
    return preco * 1.1

# %%
precos_com_imposto=[]
for preco in precos:
    precos_com_imposto.append(adicionar_imposto(preco))
print(precos_com_imposto)
# Out:
# [1100.0, 1650.0000000000002, 1375.0, 2750.0]

# %%
precos_com_imposto2 = list(map(adicionar_imposto,precos))
print(precos_com_imposto2)
# Out:
# [1100.0, 1650.0000000000002, 1375.0, 2750.0]

# %%
import pandas as pd

tabela = pd.read_excel("Base Vendas.xlsx")
display(tabela)
# Out:
#          SKU     Produto  Quantidade Vendida Primeiro Nome   Sobrenome  \
# 0     HL4379   Televisão                   5       Gabriel       Thoni
# 1     HL4379   Televisão                   3         Renan  Nascimento
# 2     HL1148      Câmera                   2        Camila      Sobral
# 3     HL1918      iPhone                   3         Clara       Bruno
# 4     HL9962     Android                   4       Eduardo     Pacheco
# ...      ...         ...                 ...           ...         ...
# 9994  HL4379   Televisão                   2          Caio    Ferreira
# 9995  HL1148      Câmera                   5           Kim    Ferreira
# 9996  HL4379   Televisão                   5          Caio      Moraes
# 9997  HL1918      iPhone                   4        Norman       Jimbo
# 9998  HL7348  SmartWatch                   1      Vinícius     Antunes
#
#             Data          Loja  Preco Unitario
# 0      6/30/2018      Curitiba            2500
# 1      9/14/2018        Recife            2500
# 2     10/21/2018     Fortaleza            2100
# 3       7/8/2018     Fortaleza            5300
# 4     12/19/2018     Fortaleza            3400
# ...          ...           ...             ...
# 9994   5/18/2018     Fortaleza            2500
# 9995    3/6/2018     Fortaleza            2100
# 9996   1/22/2018     São Paulo            2500
# 9997   6/13/2018  Porto Alegre            5300
# 9998  12/10/2018      Curitiba            1400
#
# [9999 rows x 8 columns]

# %%
tabela["Preco com Imposto"] = list(map(adicionar_imposto,  tabela['Preco Unitario']))

# %%
tabela.to_excel("Base Vendas actualizada.xlsx")

# %%
tabela = pd.read_excel("Base Vendas actualizada.xlsx")
display(tabela)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              0  HL4379   Televisão                   5       Gabriel
# 1              1  HL4379   Televisão                   3         Renan
# 2              2  HL1148      Câmera                   2        Camila
# 3              3  HL1918      iPhone                   3         Clara
# 4              4  HL9962     Android                   4       Eduardo
# ...          ...     ...         ...                 ...           ...
# 9994        9994  HL4379   Televisão                   2          Caio
# 9995        9995  HL1148      Câmera                   5           Kim
# 9996        9996  HL4379   Televisão                   5          Caio
# 9997        9997  HL1918      iPhone                   4        Norman
# 9998        9998  HL7348  SmartWatch                   1      Vinícius
#
#        Sobrenome        Data          Loja  Preco Unitario  Preco com Imposto
# 0          Thoni   6/30/2018      Curitiba            2500             2750.0
# 1     Nascimento   9/14/2018        Recife            2500             2750.0
# 2         Sobral  10/21/2018     Fortaleza            2100             2310.0
# 3          Bruno    7/8/2018     Fortaleza            5300             5830.0
# 4        Pacheco  12/19/2018     Fortaleza            3400             3740.0
# ...          ...         ...           ...             ...                ...
# 9994    Ferreira   5/18/2018     Fortaleza            2500             2750.0
# 9995    Ferreira    3/6/2018     Fortaleza            2100             2310.0
# 9996      Moraes   1/22/2018     São Paulo            2500             2750.0
# 9997       Jimbo   6/13/2018  Porto Alegre            5300             5830.0
# 9998     Antunes  12/10/2018      Curitiba            1400             1540.0
#
# [9999 rows x 10 columns]
